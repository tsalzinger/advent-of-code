// %%
@file:DependsOn("com.toldoven.aoc:aoc-kotlin-notebook:1.1.2")

// %%
import com.toldoven.aoc.notebook.AocClient

val client = AocClient.fromFile()

// %%
val day = client.interactiveDay(2025, 2)
day.viewPartOne()

// %%
val input = day.input()
input

// %%
val exampleInput = TODO()

// %%
fun String.parseInput() = TODO()

// %%
exampleInput.parseInput()

// %%
day.input().parseInput()
